# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns

# %%
wine_data = pd.read_csv("winequality-red.csv")

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine_data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine_data.groupby("quality").mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
# Can see a few of the general trends of wine quality using the quality indication of the wine above.
quality = wine_data['quality'].value_counts()

plt.figure(figsize=(14,5))
sns.barplot(x= quality.index, y= quality.values)
plt.title('Distribution of Quality', fontsize=15)
plt.xlabel('Quality')
plt.ylabel('Count')
plt.grid(linestyle='--', axis='y')
plt.show()

# %%
# Now obvious to us that the vast majority of wines are in qualities ranging from 5 - 6, now seeing correlation hotmap
plt.figure(figsize=(18, 7))
sns.heatmap(wine_data.corr(numeric_only=True), annot = True)
# Out:
# <Axes: >

# %%
#From this heatmap, we can see a few qualities have a bigger impact on quality than others. For example, the alcohol itself and
#The sulphates make quality increaase as they increase, while residular sugar has almost no correlation

# %%
wine_data["goodquality"] = [1 if x>=7 else 0 for x in wine_data['quality']] # Seperating good wine from bad wine
X = wine_data.drop(["quality", "goodquality"], axis=1) # Set axis = 1 when dropping so there are no dimensional problems later
y = wine_data['goodquality']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# This actually worked! This maps the X_train and X_test data set to a gaussian distribution, and it increased the score of LinReg
# Unfortuantely, I don't know the meaning of the warning below - it's definitely something to look into in the future
from sklearn import preprocessing
quantile_transformer = preprocessing.QuantileTransformer(
    output_distribution='normal', random_state=0)
X_train_s = quantile_transformer.fit_transform(X_train)
X_test_s = quantile_transformer.fit_transform(X_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2846: UserWarning: n_quantiles (1000) is greater than the total number of samples (480). n_quantiles is set to n_samples.
#   warnings.warn(

# %%
# Logistic Regression testing
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression()
model.fit(X_train_s, y_train)
y_pred = model.predict(X_test_s)

print("accuracy score:", accuracy_score(y_test,y_pred))
# Out:
# accuracy score: 0.8729166666666667

# %%
# Decision Tree testing
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion="entropy")
model.fit(X_train_s, y_train)
y_pred = model.predict(X_test_s)

print("accuracy score:", accuracy_score(y_test,y_pred))
# Out:
# accuracy score: 0.8625

# %%
# Using Naive Bayes
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(X_train_s, y_train)
y_pred = model.predict(X_test_s)

print("accuracy score:", accuracy_score(y_test,y_pred))
# Out:
# accuracy score: 0.85

# %%
# Using a neural network - my prediction is that it wont do well
import tensorflow as tf
tf.random.set_seed(9)

# 1. Create the model
model_1 = tf.keras.Sequential([
    tf.keras.layers.InputLayer(shape=(11,)),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1)
])

# 2. Compile the Model
model_1.compile(loss = tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.11),
                metrics = ["mae"])

# 3. Fit the model
model_1.fit(X_train_s, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0023 - mae: 1.0023
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.2428 - mae: 0.2428
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.1525 - mae: 0.1525
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.1392 - mae: 0.1392
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.1363 - mae: 0.1363
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - loss: 0.1382 - mae: 0.1382
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 0.1367 - mae: 0.1367
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.1345 - mae: 0.1345
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 0.1404 - mae: 0.1404
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.1352 - mae: 0.1352
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 0.1332 - mae: 0.1332
# Epoch 12/100
# ...

# %%
results = model_1.evaluate(X_test, y_test, verbose=1)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3443 - mae: 0.3443

# %%
loss, accuracy = model_1.evaluate(X_test_s, y_test)
print("Accuracy score (Keras):", accuracy)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1710 - mae: 0.1710
# Accuracy score (Keras): 0.17095191776752472

# %% [markdown]
# # Though the loss was low, it still did not a high accuracy score like others, which were in the 80%. This means that out of all the methods I tested today, Logistic Regression is the best!
